# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [Lidya Dwi Astuti]
# - **Email:** [lidyadwiastuti00@gmail.com]
# - **ID Dicoding:** [Lidya Dwi Astuti]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Berapa banyak peminjaman sepeda di kondisi cuaca salju ?
# - Berapa banyak peminjaman sepeda saat libur ?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
df = pd.read_csv('/content/day.csv')

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %%
df.head(10)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
# 5        6  2011-01-06       1   0     1        0        4           1
# 6        7  2011-01-07       1   0     1        0        5           1
# 7        8  2011-01-08       1   0     1        0        6           0
# 8        9  2011-01-09       1   0     1        0        0           0
# 9       10  2011-01-10       1   0     1        0        1           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# ...

# %% [markdown]
# **Insight:**
# - berhasil menampilkan sepuluh baris data pertama dari days.csv
# - data days.csv memiliki 16 kolom

# %% [markdown]
# ### Cleaning Data

# %%
df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# **Insight:**
# - data days.csv tidak memiliki missing value
# - kolom date days untuk tipe datanya tidak sesuai dengan tipe data date time

# %%
df['dteday'] = pd.to_datetime(df['dteday'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
import seaborn as sns
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# **Insight:**
# - Visualisasi untuk korelasi pengecek seberapa pengaruh variabel 1 dan 2
# - untuk cara membacanya bisa dimulai dari baris horizontal atau vertikal atau sumbu x dan y.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
df.query('weathersit == 3')
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 25        26 2011-01-26       1   0     1        0        3           1
# 68        69 2011-03-10       1   0     3        0        4           1
# 89        90 2011-03-31       2   0     3        0        4           1
# 105      106 2011-04-16       2   0     4        0        6           0
# 248      249 2011-09-06       3   0     9        0        2           1
# 249      250 2011-09-07       3   0     9        0        3           1
# 250      251 2011-09-08       3   0     9        0        4           1
# 284      285 2011-10-12       4   0    10        0        3           1
# 291      292 2011-10-19       4   0    10        0        3           1
# 301      302 2011-10-29       4   0    10        0        6           0
# 319      320 2011-11-16       4   0    11        0        3           1
# 324      325 2011-11-21       4   0    11        0        1           1
# ...

# %%
df.weathersit.value_counts()
# Out:
# weathersit
# 1    463
# 2    247
# 3     21
# Name: count, dtype: int64

# %%
weather_sit =df[df['weathersit']==3]

# %%
plt.figure(figsize=(8,4))
plt.bar(df['weathersit'].value_counts().index, df['weathersit'].value_counts().values, tick_label=['Cerah','Mendung','Salju'], color=['#dfdfdf', 'grey','blue'])
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
df['workingday'].value_counts()
# Out:
# workingday
# 1    500
# 0    231
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,4))
plt.bar(df['workingday'].value_counts().index, df['workingday'].value_counts().values, tick_label=['weekday', 'weekend'], color=['grey','blue'])
plt.show()

# %% [markdown]
# **Insight:**
# - untuk jumlah peminjaman sepeda di cuaca salju jauh lebih sedikit dibandingkan cuaca cerah dan mendung.
# - untuk jumlah peminjaman dihari libur jauh lebih sedikit dibandingkan hari biasa.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Jumlah peminjaman di sepeda dicuaca Salju sebanyak 21.
# - Jumlah peminjaman di hari libur sebanyak 231.
